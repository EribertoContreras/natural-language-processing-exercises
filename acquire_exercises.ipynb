# %% [markdown]
# By the end of this exercise, you should have a file named acquire.py that contains the specified functions. If you wish, you may break your work into separate files for each website (e.g. acquire_codeup_blog.py and acquire_news_articles.py), but the end function should be present in acquire.py (that is, acquire.py should import get_blog_articles from the acquire_codeup_blog module.)
#
# 1) Codeup Blog Articles
#
# - Visit Codeup's Blog and record the urls for at least 5 distinct blog posts. For each post, you should scrape at least the post's title and content.
#
# - Encapsulate your work in a function named get_blog_articles that will return a list of dictionaries, with each dictionary representing one article. The shape of each dictionary should look like this:
#
#
# `{
#     'title': 'the title of the article',
#     'content': 'the full text content of the article'
# }`
#
# - Plus any additional properties you think might be helpful.
#
# `Bonus:`  Scrape the text of all the articles linked on codeup's blog page.
#
# 2) News Articles
#
# - We will now be scraping text data from inshorts, a website that provides a brief overview of many different topics.
#
# - Write a function that scrapes the news articles for the following topics:
#
#     - Business
#     - Sports
#     - Technology
#     - Entertainment
# The end product of this should be a function named get_news_articles that returns a list of dictionaries, where each dictionary has this shape:
#
#
# `{
#     'title': 'The article title',
#     'content': 'The article content',
#     'category': 'business' # for example
# }`
#
# - `Hints:`
#
# - Start by inspecting the website in your browser. Figure out which elements will be useful.
# - Start by creating a function that handles a single article and produces a dictionary like the one above.
# - Next create a function that will find all the articles on a single page and call the function you created in the last step for every article on the page.
# - Now create a function that will use the previous two functions to scrape the articles from all the pages that you need, and do any additional processing that needs to be done.
#
# 3) `Bonus:` cache the data
#
# Write your code such that the acquired data is saved locally in some form or fashion. Your functions that retrieve the data should prefer to read the local data instead of having to make all the requests everytime the function is called. Include a boolean flag in the functions to allow the data to be acquired "fresh" from the actual sources (re-writing your local cache).

# %% [markdown]
# ***

# %% [markdown]
# 1) Codeup Blog Articles
#
# - Visit Codeup's Blog and record the urls for at least 5 distinct blog posts. For each post, you should scrape at least the post's title and content.
#
# - Encapsulate your work in a function named get_blog_articles that will return a list of dictionaries, with each dictionary representing one article. The shape of each dictionary should look like this:
#
#
# `{
#     'title': 'the title of the article',
#     'content': 'the full text content of the article'
# }`
#
# - Plus any additional properties you think might be helpful.
#
# `Bonus:`  Scrape the text of all the articles linked on codeup's blog page.

# %%
from requests import get
from bs4 import BeautifulSoup
import os
import pandas as pd

# %%
def blog_articles():
    url = 'https://codeup.com/blog/'
    headers = {'User-Agent': 'Codeup Data Science'} # Some websites don't accept the pyhon-requests default user-agent

    response = get(url, headers=headers)

    soup = BeautifulSoup(response.content, 'html.parser')

    links = [a['href'] for a in soup.select('h2 a[href]')]

    articles = []

    for url in links:
        url_response = get(url, headers=headers)
        soup = BeautifulSoup(url_response.text)
        
        title = soup.find('h1', class_='entry-title'). text
        content = soup.find('div', class_='entry-content').text.strip()
        
        article_dict = {
            'title': title,
            'content': content,
        }
        
        articles.append(article_dict)
        # use code like (articles[0:5]) to summon articles
    return pd.DataFrame(articles)
blog_articles()
# Out:
#                                                 title  \
# 0   What Jobs Can You Get After a Coding Bootcamp?...
# 1   What Jobs Can You Get After a Coding Bootcamp?...
# 2   Is Our Cloud Administration Program Right for ...
# 3   5 Reasons To Attend Our New Cloud Administrati...
# 4   What Jobs Can You Get After a Coding Bootcamp?...
# 5   What Jobs Can You Get After a Coding Bootcamp?...
# 6   In-Person Workshop: Learn to Code – JavaScript...
# 7   In-Person Workshop: Learn to Code – Python on ...
# 8   Free JavaScript Workshop at Codeup Dallas on 6/28
# 9   Is Our Cloud Administration Program Right for ...
# 10                                PRIDE in Tech Panel
# 11  Inclusion at Codeup During Pride Month (and Al...
# 12                   Mental Health First Aid Training
# 13  Codeup Dallas: How to Succeed at a Coding Boot...
# 14  5 Reasons To Attend Our New Cloud Administrati...
# 15                      Learn to Code: Python on 5/21
# 16                     Codeup Dallas Joins Career Day
# 17  Project Quest Info Session: IT Jumpstart on Ma...
# 18  From Bootcamp to Bootcamp | A Military Appreci...
# 19  Our Acquisition of the Rackspace Cloud Academy...
# 20                  Learn to Code: HTML & CSS on 4/30
# 21             Learn to Code: Python Workshop on 4/23
#
#                                               content
# 0   Have you been considering a career in Cloud Ad...
# 1   If you are interested in embarking on a career...
# 2   Changing careers can be scary. The first thing...
# 3   Come Work In The Cloud\nWhen your Monday rolls...
# 4   Have you been considering a career in Cloud Ad...
# 5   If you are interested in embarking on a career...
# 6   Join us for our live in-person JavaScript cras...
# 7   According to LinkedIn, the “#1 Most Promising ...
# 8   Event Info: \nLocation – Codeup Dallas\nTime –...
# 9   Changing careers can be scary. The first thing...
# 10  In celebration of PRIDE month, join our Codeup...
# 11  Happy Pride Month! Pride Month is a dedicated ...
# 12  As a student of Codeup, going through a massiv...
# 13  This event is the perfect opportunity for peop...
# 14  Come Work In The Cloud\nWhen your Monday rolls...
# 15  According to LinkedIn, the “#1 Most Promising ...
# 16  Last week our Codeup Dallas team participated ...
# 17  Join our grant partner Project Quest as they d...
# 18  In honor of Military Appreciation Month, join ...
# 19  Just about a year ago on April 16th, 2021 we a...
# 20  HTML & CSS are the design building blocks of a...
# 21  According to LinkedIn, the “#1 Most Promising ...

# %% [markdown]
# ## Pulling it individually

# %%
    def in_person_workshop_data():
        url = "https://codeup.com/workshops/in-person-workshop-learn-to-code-python-on-7-19/"
        headers = {'User-Agent': 'Codeup Data Science'} # Some websites don't accept the pyhon-requests default user-agent
        response = get(url, headers=headers)
        # Make a soup variable holding the response content
        soup = BeautifulSoup(response.content, 'html.parser')
        title = soup.find('h1', class_='entry-title'). text
        content = soup.find('div', class_='entry-content').text.strip()
        article = []
        article_dict = {
            'title': title,
            'content': content,
        }

        article.append(article_dict)
        return article
    def free_javascript_data():
        url = "https://codeup.com/workshops/dallas/free-javascript-workshop-at-codeup-dallas-on-6-28/"
        headers = {'User-Agent': 'Codeup Data Science'} # Some websites don't accept the pyhon-requests default user-agent
        response = get(url, headers=headers)
        response.text
        # Make a soup variable holding the response content
        soup = BeautifulSoup(response.content, 'html.parser')
        title = soup.find('h1', class_='entry-title'). text
        content = soup.find('div', class_='entry-content').text.strip()
        article = []
        article_dict = {
            'title': title,
            'content': content,
        }

        article.append(article_dict)
        return article
    def tips_for_prospective_students():
        url = "https://codeup.com/tips-for-prospective-students/is-our-cloud-administration-program-right-for-you/"
        headers = {'User-Agent': 'Codeup Data Science'} # Some websites don't accept the pyhon-requests default user-agent
        response = get(url, headers=headers)
        response.text
        # Make a soup variable holding the response content
        soup = BeautifulSoup(response.content, 'html.parser')
        title = soup.find('h1', class_='entry-title'). text
        content = soup.find('div', class_='entry-content').text.strip()
        article = []
        article_dict = {
            'title': title,
            'content': content,
        }

        article.append(article_dict)
        return article
    def pride_in_tech_panel():
        url = "https://codeup.com/workshops/pride-in-tech-panel/"
        headers = {'User-Agent': 'Codeup Data Science'} # Some websites don't accept the pyhon-requests default user-agent
        response = get(url, headers=headers)
        response.text
        # Make a soup variable holding the response content
        soup = BeautifulSoup(response.content, 'html.parser')
        title = soup.find('h1', class_='entry-title'). text
        content = soup.find('div', class_='entry-content').text.strip()
        article = []
        article_dict = {
            'title': title,
            'content': content,
        }

        article.append(article_dict)
        return article
    def tips_for_prospective_students():
        url = "https://codeup.com/tips-for-prospective-students/mental-health-first-aid-training/"
        headers = {'User-Agent': 'Codeup Data Science'} # Some websites don't accept the pyhon-requests default user-agent
        response = get(url, headers=headers)
        response.text
        # Make a soup variable holding the response content
        soup = BeautifulSoup(response.content, 'html.parser')
        title = soup.find('h1', class_='entry-title'). text
        content = soup.find('div', class_='entry-content').text.strip()
        article = []
        article_dict = {
            'title': title,
            'content': content,
        }

        article.append(article_dict)
        return article

# %%
tips_for_prospective_students()
# Out:
# [{'title': 'Mental Health First Aid Training',
#   'content': 'As a student of Codeup, going through a massive career transition can be mentally taxing. Did you know that members of our student-facing staff and human resources team are trained in Mental Health First Aid? Let’s dive into what that means for Codeup!\xa0\nMental Health First Aid Training\xa0\nSome of our Codeup staff that works directly with our students are trained in Mental Health First Aid. This includes members of our student experience team, career coaches, and the human resources department. This training was courtesy of the Center for Health Care Services in San Antonio. They graciously provided the funding and training for our team in this pilot training program.\xa0\nWhat is Mental Health First Aid? According to mentalhhealthfirstaid.org, “is a course that teaches you how to identify, understand, and respond to signs of mental illness and substance use disorders. The training gives you the skills you need to reach out and provide initial help and support to someone who may be developing a mental health or substance use problem or experiencing a crisis”.\nTo be clear, our staff are not licensed, mental health professionals. What MHFA equips our staff with are tools to gauge risk and connect students and staff with the help they might need. This might include recognizing something in a meeting, picking up on cues during a casual conversation, or acting on a pattern behavior.\xa0\nHow does this help our students?\nMany who go through Codeup’s programs will tell you it is both rewarding and challenging all at the same time. Some students have compared learning at Codeup to\xa0 “drinking from a firehouse”. You learn so much at once, so fast. This style of learning if you are not used to it can be taxing on anyone’s mental fortitude. This allows our staff who work closely with the students to be able to identify if a student is in need of mental health help.\xa0\nConsider Your Career Change Today\nWhy does this skill set matter? You! We’re here to support your career transition as best we can, and Mental Health First Aid training is just one small piece of that larger support effort. Learn more about how we can support your career transition by applying today.'}]

# %% [markdown]
# ***
# 2) News Articles
#
# - We will now be scraping text data from inshorts, a website that provides a brief overview of many different topics.
#
# - Write a function that scrapes the news articles for the following topics:
#
#     - Business
#     - Sports
#     - Technology
#     - Entertainment
# The end product of this should be a function named get_news_articles that returns a list of dictionaries, where each dictionary has this shape:
#
#
# `{
#     'title': 'The article title',
#     'content': 'The article content',
#     'category': 'business' # for example
# }`
#
# - `Hints:`
#
# - Start by inspecting the website in your browser. Figure out which elements will be useful.
# - Start by creating a function that handles a single article and produces a dictionary like the one above.
# - Next create a function that will find all the articles on a single page and call the function you created in the last step for every article on the page.
# - Now create a function that will use the previous two functions to scrape the articles from all the pages that you need, and do any additional processing that needs to be done.

# %%
def get_shorts_articles(categories, refresh = False):
        
    #Creating an empty list to contain DataFrames of scraped data components:
    inshorts_articles = []
   #for-loop to pull categories:
    for category in categories:
        #Creating an empty dataframe:
        is_articles = pd.DataFrame()
        #making url:
        url = f'https://inshorts.com/en/read/{category}'
        #making header so it doesn't use'python-request':
        headers = {'User-Agent': 'Codeup Data Science'}
        #response from the website:
        response = get(url, headers=headers)
        #Creating a beautifulSoup:
        soup = BeautifulSoup(response.content, 'html.parser') 
        # creating a list for titles:
        titles = soup.find_all(itemprop = 'headline')
        #Creating a list of all article bodies in the given category
        contents = soup.find_all(itemprop = 'articleBody')
        #Adding 'title' column to DataFrame containing title text for each article:
        is_articles['title'] = [title.text for title in titles]
        #Adding 'contents' column to DataFrame containing article body text for each article
        is_articles['contents'] = [content.text for content in contents]
        #Adding 'category' column to list category for each article in the category:
        is_articles['category'] = category
        #Appending DataFrame for each category to overall list of DataFrames:
        inshorts_articles.append(is_articles)

    #Concatenating all of the DataFrames in the list to create one large DataFrame:
    inshorts = pd.concat(inshorts_articles)
    #Returning final DataFrame:
    return inshorts
""" use this to summon code properly, categories = ['world', 'science', 'technology', 'entertainment'], inshorts = get_shorts_articles(categories), inshorts"""
# Out:
# " use this to summon code properly, categories = ['world', 'science', 'technology', 'entertainment'], inshorts = get_shorts_articles(categories), inshorts"

# %%
#categories chosen
categories = ['world', 'science', 'technology', 'entertainment']
inshorts = get_shorts_articles(categories)
inshorts
# Out:
#                                                 title  \
# 0   West can't isolate Russia & reverse its develo...
# 1   What is the deadly Ebola-like Marburg virus di...
# 2   Sunak praises father-in-law Narayana Murthy, s...
# 3   Outbreak of deadly Ebola-like Marburg virus di...
# 4    COVID-19 outbreak at resort in China leaves 2...
# ..                                                ...
# 20  'PS-1' director Mani Ratnam receives legal not...
# 21  Samantha to be guest at Indian Film Festival o...
# 22  Ranbir always caught my attention with his wor...
# 23  Grace & style of Dhanush is something to behol...
# 24  SRK's look from 'Dunki' leaked, actor spotted ...
#
#                                              contents       category
# 0   Russian President Vladimir Putin said on Monda...          world
# 1   An outbreak of Marburg virus disease has been ...          world
# 2   One of the frontrunners for the UK PM's post, ...          world
# 3   Ghana has declared the country's first outbrea...          world
# 4   Over 2,000 tourists are stranded in the city o...          world
# ..                                                ...            ...
# 20  Filmmaker Mani Ratnam and actor Vikram have re...  entertainment
# 21  Actress Samantha Ruth Prabhu will be a key gue...  entertainment
# 22  'Shamshera' director Karan Malhotra has said t...  entertainment
# 23  Regé-Jean Page, speaking about Dhanush in 'The...  entertainment
# 24  Actor Shah Rukh Khan's look from his upcoming ...  entertainment
#
# [98 rows x 3 columns]
